# %%
import pandas as pd

# %%
df = pd.read_csv('job_detail_QC_26158_03_30.csv')

# %%
df.head()
# Out:
#                          Title               Date Posted  \
# 0     food processing labourer  Posted on March 08, 2024
# 1                      dentist  Posted on March 08, 2024
# 2  retail sales representative  Posted on March 15, 2024
# 3             dental hygienist  Posted on March 06, 2024
# 4          warehouse associate  Posted on March 28, 2024
#
#                                             Employer  \
# 0                                     Conagra Brands
# 1  CLINIQUE DENTAIRE             SAINT-JEAN-PORT-...
# 2                                      Lowe's Canada
# 3                                  Carrière Dentaire
# 4                               Sugatsune Canada Inc
#
#                    Location      Salary         Work Hours  \
# 0            Boisbriand, QC         NaN                NaN
# 1  Saint-Jean-Port-Joli, QC         NaN                NaN
# 2           Charlemagne, QC         NaN                NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26158 entries, 0 to 26157
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             24799 non-null  object
#  1   Date Posted       24799 non-null  object
#  2   Employer          24799 non-null  object
#  3   Location          24799 non-null  object
#  4   Salary            10805 non-null  object
#  5   Work Hours        5780 non-null   object
#  6   Employment Type   20333 non-null  object
#  7   Start Date        20324 non-null  object
#  8   Vacancies         24761 non-null  object
#  9   Languages         2165 non-null   object
#  10  Education         2144 non-null   object
#  11  Experience        2144 non-null   object
#  12  Responsibilities  1703 non-null   object
#  13  Benefits          1262 non-null   object
#  14  Valid Through     23945 non-null  object
#  15  url               26158 non-null  object
# dtypes: object(16)
# ...

# %%
df.describe()
# Out:
#                 Title               Date Posted Employer      Location  \
# count           24799                     24799    24799         24799
# unique           3914                       113     6410           813
# top     driver, truck  Posted on March 27, 2024    Metro  Montréal, QC
# freq              282                      1586      390          2885
#
#             Salary         Work Hours                Employment Type  \
# count        10805               5780                          20333
# unique        1656                197                             84
# top     20.00 HOUR  40 hours per week  Permanent employmentFull time
# freq           640               2382                          13201
#
#                         Start Date  Vacancies Languages  \
# count                        20324      24761      2165
# unique                           1         38         4
# top     Starts as soon as possible  1 vacancy    French
# ...
