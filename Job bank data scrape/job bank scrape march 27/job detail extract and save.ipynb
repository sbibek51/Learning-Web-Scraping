# %%
import csv
from bs4 import BeautifulSoup
import requests

def scrape_job_details(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    job_details = {}

    # Extracting job details
    title_elem = soup.find('span', property='title')
    job_details['Title'] = title_elem.get_text().strip() if title_elem else ''

    date_elem = soup.find('span', property='datePosted')
    job_details['Date Posted'] = date_elem.get_text().strip() if date_elem else ''

    employer_elem = soup.find('span', property='name')
    job_details['Employer'] = employer_elem.get_text().strip() if employer_elem else ''

    location_elem = soup.find('span', property='addressLocality')
    region_elem = soup.find('span', property='addressRegion')
    job_details['Location'] = f"{location_elem.get_text().strip()}, {region_elem.get_text().strip()}" if location_elem and region_elem else ''

    salary_elem = soup.find('span', property='value')
    unit_elem = soup.find('span', class_='hidden', property='unitText')
    job_details['Salary'] = f"{salary_elem.get_text().strip()} {unit_elem.get_text().strip()}" if salary_elem and unit_elem else ''

    employment_type_elem = soup.find('span', property='employmentType')
    job_details['Employment Type'] = employment_type_elem.get_text().strip() if employment_type_elem else ''

    start_date_elem = soup.find('span', class_='wb-inv', string='Start date').find_next_sibling() if soup.find('span', class_='wb-inv', string='Start date') else None
    job_details['Start Date'] = start_date_elem.get_text().strip() if start_date_elem else ''

    vacancies_elem = soup.find('span', class_='wb-inv', string='vacancies').find_next_sibling() if soup.find('span', class_='wb-inv', string='vacancies') else None
    job_details['Vacancies'] = vacancies_elem.get_text().strip() if vacancies_elem else ''

    description_elem = soup.find('span', class_='hidden', property='description')
    job_details['Description'] = description_elem.get_text().strip() if description_elem else ''

    languages_elem = soup.find('h4', string='Languages').find_next_sibling() if soup.find('h4', string='Languages') else None
    job_details['Languages'] = languages_elem.get_text().strip() if languages_elem else ''

    education_elem = soup.find('h4', string='Education').find_next_sibling() if soup.find('h4', string='Education') else None
    job_details['Education'] = education_elem.get_text().strip() if education_elem else ''

    experience_elem = soup.find('h4', string='Experience').find_next_sibling() if soup.find('h4', string='Experience') else None
    job_details['Experience'] = experience_elem.get_text().strip() if experience_elem else ''

    # Additional scraping for responsibilities
    responsibilities_elem = soup.find('div', property='responsibilities')
    if responsibilities_elem:
        job_details['Responsibilities'] = ', '.join([li.get_text().strip() for li in responsibilities_elem.find_all('li')])
    else:
        job_details['Responsibilities'] = ''

    return job_details

# Read URLs from CSV file
job_links = []
with open('job_links.csv', 'r', newline='', encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile)
    next(reader)  # Skip header
    for row in reader:
        job_links.append(row[0])

# Scrape job details for each URL
job_details_list = []
for url in job_links:
    job_details = scrape_job_details(url)
    job_details_list.append(job_details)

# Write job details to CSV file
with open('job_details.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['Title', 'Date Posted', 'Employer', 'Location', 'Salary', 'Employment Type', 'Start Date', 'Vacancies', 'Description', 'Languages', 'Education', 'Experience', 'Responsibilities']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for job_details in job_details_list:
        writer.writerow(job_details)

print("Job details have been saved to job_details.csv")
# Out:
# Job details have been saved to job_details.csv

# %%
import pandas as pd
df = pd.read_csv('job_details.csv')

# %%
df.columns
# Out:
# Index(['Title', 'Date Posted', 'Employer', 'Location', 'Salary',
#        'Employment Type', 'Start Date', 'Vacancies', 'Description',
#        'Languages', 'Education', 'Experience', 'Responsibilities'],
#       dtype='object')

# %%
df.head()
# Out:
#                                Title                  Date Posted  \
# 0            food service supervisor  Posted on December 25, 2023
# 1              tour guide supervisor     Posted on March 26, 2024
# 2  plumber, residential construction     Posted on March 15, 2024
# 3                       veterinarian  Posted on February 08, 2024
# 4      automotive service technician   Posted on January 27, 2024
#
#                                         Employer         Location  \
# 0  Government of Canada / Gouvernement du Canada  Yellowknife, NT
# 1  Government of Canada / Gouvernement du Canada  Yellowknife, NT
# 2  Government of Canada / Gouvernement du Canada  Yellowknife, NT
# 3  Government of Canada / Gouvernement du Canada  Yellowknife, NT
# 4  Government of Canada / Gouvernement du Canada  Yellowknife, NT
#
#                                               Salary  \
# 0                             $16.50HOUR hourly HOUR
# 1                             $25.00HOUR hourly HOUR
# 2  $50.00 to $70.00HOUR hourly (To be negotiated)...
# 3  $52.50 to $60.00HOUR hourly (To be negotiated)...
# 4                             $39.77HOUR hourly HOUR
#
#                  Employment Type                  Start Date    Vacancies  \
# 0  Permanent employmentFull time  Starts as soon as possible  2 vacancies
# 1   Seasonal employmentFull time                         NaN    1 vacancy
# 2  Permanent employmentFull time  Starts as soon as possible  2 vacancies
# 3  Permanent employmentFull time  Starts as soon as possible  3 vacancies
# 4  Permanent employmentFull time  Starts as soon as possible  3 vacancies
#
#                                          Description Languages  \
# 0  Education: Secondary (high) school graduation ...   English
# 1  Education: College/CEGEP. Work setting: Remote...   English
# 2  Education: Registered Apprenticeship certifica...   English
# 3  Education: Degree in medicine, dentistry, vete...   English
# 4  Education: Registered Apprenticeship certifica...   English
#
#                                            Education  \
# 0     Secondary (high) school graduation certificate
# 1                                      College/CEGEP
# 2  Registered Apprenticeship certificate\n\nor eq...
# 3  Degree in medicine, dentistry, veterinary medi...
# 4  Registered Apprenticeship certificate\n\nor eq...
#
#                      Experience  \
# 0   1 year to less than 2 years
# 1  2 years to less than 3 years
# 2   1 year to less than 2 years
# 3   1 year to less than 2 years
# 4  3 years to less than 5 years
#
#                                     Responsibilities
# 0  Establish methods to meet work schedules, Supe...
# 1  Perform same duties as workers supervised, Ass...
# 2                                                NaN
# 3  Diagnose diseases or abnormal conditions in in...
# 4  Inspect motor in operation, road test motor ve...

# %%
df.shape
# Out:
# (187, 13)

# %%
df['Start Date'].unique()
# Out:
# array(['Starts as soon as possible', nan], dtype=object)

# %%
df.tail()
# Out:
#                    Title                  Date Posted  \
# 182       truck operator     Posted on March 04, 2024
# 183  supermarket cashier  Posted on February 27, 2024
# 184      delivery driver  Posted on December 12, 2023
# 185       office manager  Posted on February 14, 2024
# 186   restaurant manager   Posted on January 17, 2024
#
#                                           Employer         Location  \
# 182  Government of Canada / Gouvernement du Canada  Yellowknife, NT
# 183  Government of Canada / Gouvernement du Canada  Yellowknife, NT
# 184  Government of Canada / Gouvernement du Canada  Yellowknife, NT
# 185  Government of Canada / Gouvernement du Canada  Hay River, , NT
# 186  Government of Canada / Gouvernement du Canada  Yellowknife, NT
#
#                         Salary                Employment Type  \
# 182                        NaN                            NaN
# 183     $16.05HOUR hourly HOUR  Permanent employmentFull time
# 184     $21.00HOUR hourly HOUR  Permanent employmentFull time
# 185     $25.00HOUR hourly HOUR  Permanent employmentFull time
# 186  $70,000YEAR annually YEAR  Permanent employmentFull time
#
#                      Start Date    Vacancies  \
# 182  Starts as soon as possible    1 vacancy
# 183  Starts as soon as possible  5 vacancies
# 184  Starts as soon as possible    1 vacancy
# 185  Starts as soon as possible  2 vacancies
# 186  Starts as soon as possible    1 vacancy
#
#                                            Description  Languages  \
# 182  Make Great Money! Be Appreciated for What You ...        NaN
# 183  Education: No degree, certificate or diploma. ...    English
# 184  Education: No degree, certificate or diploma. ...    English
# 185  Education: Bachelor's degree. or equivalent ex...  Bilingual
# 186  Education: College, CEGEP or other non-univers...    English
#
#                                              Education  \
# 182                                                NaN
# 183                  No degree, certificate or diploma
# 184                  No degree, certificate or diploma
# 185      Bachelor's degree\n\nor equivalent experience
# 186  College, CEGEP or other non-university certifi...
#
#                       Experience  \
# 182                          NaN
# 183      1 to less than 7 months
# 184                   Will train
# 185  1 year to less than 2 years
# 186  1 year to less than 2 years
#
#                                       Responsibilities
# 182                                                NaN
# 183                                                NaN
# 184  Deliver and pick up messages, parcels, and oth...
# 185  Delegate work to office support staff, Establi...
# 186  Plan, organize, direct, control and evaluate d...
