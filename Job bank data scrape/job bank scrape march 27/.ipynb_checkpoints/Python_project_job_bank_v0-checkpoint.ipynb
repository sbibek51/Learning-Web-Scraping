# %%
import pandas as pd

# %%
df = pd.read_csv('job_detail_ON_20400_03_29.csv')

# %%
df.shape
# Out:
# (20400, 16)

# %%
df.columns
# Out:
# Index(['Title', 'Date Posted', 'Employer', 'Location', 'Salary', 'Work Hours',
#        'Employment Type', 'Start Date', 'Vacancies', 'Languages', 'Education',
#        'Experience', 'Responsibilities', 'Benefits', 'Valid Through', 'url'],
#       dtype='object')

# %%
df.head(3)
# Out:
#                    Title                  Date Posted  \
# 0   prosthetic assistant     Posted on March 23, 2024
# 1           cabinetmaker  Posted on February 28, 2024
# 2  restoration carpenter     Posted on March 18, 2024
#
#                          Employer         Location      Salary  \
# 0                           Metro       Sarnia, ON         NaN
# 1                 Sympro Mfg Inc.  Mississauga, ON  27.00 HOUR
# 2  Supra Restoration Services LTD     Bradford, ON  30.00 HOUR
#
#                 Work Hours                                 Employment Type  \
# 0                      NaN                                             NaN
# 1  30 to 40 hours per week                   Permanent employmentFull time
# 2        40 hours per week  Term or contract (ending: 2027-07-02)Full time
#
#                    Start Date    Vacancies Languages  \
# 0  Starts as soon as possible    1 vacancy       NaN
# 1  Starts as soon as possible    1 vacancy   English
# ...

# %%
df.tail(3)
# Out:
#                                    Title               Date Posted  \
# 20397  administrative assistant - office  Posted on March 12, 2024
# 20398                                NaN                       NaN
# 20399           human resources director  Posted on March 26, 2024
#
#                                     Employer         Location      Salary  \
# 20397           Atlantic Immigration Limited  Mississauga, ON  20.00 HOUR
# 20398                                    NaN              NaN         NaN
# 20399  Waterloo Region District School Board    Kitchener, ON         NaN
#
#                     Work Hours                Employment Type  \
# 20397  35 to 44 hours per week  Permanent employmentFull time
# 20398                      NaN                            NaN
# 20399                      NaN  Permanent employmentFull time
#
#                        Start Date    Vacancies Languages  \
# 20397  Starts as soon as possible  3 vacancies   English
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20400 entries, 0 to 20399
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             20001 non-null  object
#  1   Date Posted       20001 non-null  object
#  2   Employer          20001 non-null  object
#  3   Location          20001 non-null  object
#  4   Salary            14884 non-null  object
#  5   Work Hours        11338 non-null  object
#  6   Employment Type   18414 non-null  object
#  7   Start Date        19542 non-null  object
#  8   Vacancies         19811 non-null  object
#  9   Languages         11338 non-null  object
#  10  Education         11309 non-null  object
#  11  Experience        11309 non-null  object
#  12  Responsibilities  10725 non-null  object
#  13  Benefits          3675 non-null   object
#  14  Valid Through     16023 non-null  object
#  15  url               20400 non-null  object
# dtypes: object(16)
# ...

# %%
df.describe()
# Out:
#                           Title               Date Posted    Employer  \
# count                     20001                     20001       20001
# unique                     3158                        32       11552
# top     food service supervisor  Posted on March 26, 2024  Home Depot
# freq                        895                      2127         237
#
#                Location      Salary         Work Hours  \
# count             20001       14884              11338
# unique              709        1480                326
# top     Mississauga, ON  17.00 HOUR  40 hours per week
# freq               1933        1122               2712
#
#                       Employment Type                  Start Date  Vacancies  \
# count                           18414                       19542      19811
# unique                             68                           1         35
# top     Permanent employmentFull time  Starts as soon as possible  1 vacancy
# ...
