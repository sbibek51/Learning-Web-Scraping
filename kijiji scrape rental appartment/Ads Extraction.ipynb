# %%
# %load Ads_extraction.py
import pandas as pd
from datetime import datetime
import re
import Utils as utils
import os

# Path to the CSV file containing URLs
csv_file_path = 'kijiji_rental_ads_url.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)
df.head()
# Extract the URLs as a list
url_list = df['URL'].tolist()  # Assuming 'URL' is the column containing the URLs

data = []
counter = 0
start_time = datetime.now()

# Loop through the list of URLs and process each one
for url in url_list:

    soup = utils.get_soup(url)
    if soup:
        # Initialize a dictionary to store the extracted data for this URL
        ad_data = {}

        title_el = soup.find('h1', class_='title-4206718449')
        if title_el is None:
            continue

        # Extract title, price, address, and posting date
        ad_data['Title'] = title_el.text.strip()

        # Extract Price
        price_elem = soup.find(class_='priceWrapper-3915768379')
        price_text = ''
        if price_elem:
            price_text = price_elem.text.strip()
        else:
            backup_price_elem = soup.find(class_='currentPrice-231544276')
            price_text = backup_price_elem.text.strip() if backup_price_elem else None

        ad_data['Price($)'] = ''.join(re.findall(r'\d+', price_text))

        # Extract Address
        address_elem = soup.find(itemprop='address')
        ad_data['Address'] = address_elem.text.strip() if address_elem else None

        # Find the div with class "datePosted"
        date_posted_div = soup.find('div', class_='datePosted-1776470403')

        posted_datetime = ''
        # Extract the datetime attribute from the time tag
        if date_posted_div:
            time_tag = date_posted_div.find('time')
            if time_tag and 'datetime' in time_tag.attrs:
                datetime_str = time_tag['datetime']

                # Parse the datetime string into a datetime object
                posted_datetime = datetime.strptime(datetime_str, "%Y-%m-%dT%H:%M:%S.%fZ")

        ad_data['Date Posted'] = posted_datetime

        # Extract bedrooms, bathrooms, and building type if title_attributes is present
        title_attributes = soup.find(class_='titleAttributes-183069789')
        if title_attributes:
            title_attributes = title_attributes.find_all('li', class_='noLabelAttribute-262950866')
            for attr in title_attributes:
                if 'Bedrooms' in attr.span.text:
                    ad_data['Bedrooms'] = attr.span.text.split(': ')[-1]
                elif 'Bathrooms' in attr.span.text:
                    ad_data['Bathrooms'] = attr.span.text.split(': ')[-1]
                else:
                    ad_data['Building Type'] = attr.span.text

        # Handle case where title_attributes is not present
        else:
            ad_data['Bedrooms'] = None
            ad_data['Bathrooms'] = None
            ad_data['Building Type'] = None

        # Find the container for the "Utilities Included" section
        utilities_included_container = soup.find('h4', string='Utilities Included')

        # Extract the "Utilities Included" section if it exists
        utilities_text = ''
        if utilities_included_container:
            utilities_included_section = utilities_included_container.find_next('ul')
            if utilities_included_section:
                utilities_element = utilities_included_section.find_all('li')
                utilities_text = ','.join(
                    f"{item.get_text(strip=True)}_Yes" if 'Yes' in item.find('svg').get('aria-label',
                                                                                        '') else f"{item.get_text(strip=True)}_No" if 'No' in item.find(
                        'svg').get('aria-label', '') else f"{item.get_text(strip=True)}" for item in utilities_element)

        # Print the combined text with Yes/No indicators
        ad_data['Utilities'] = utilities_text

        # Get and print each section's text
        ad_data['Wi-Fi and More'] = utils.get_section_text(soup, 'Wi-Fi and More', 'h4', 'ul')

        ad_data['Parking Included'] = utils.get_section_text(soup, 'Parking Included', 'dt', 'dd')

        ad_data['Agreement Type'] = utils.get_section_text(soup, 'Agreement Type', 'dt', 'dd')

        ad_data['Move-In Date'] = utils.get_section_text(soup, 'Move-In Date', 'dt', 'dd')

        ad_data['Pet Friendly'] = utils.get_section_text(soup, 'Pet Friendly', 'dt', 'dd')

        ad_data['Size (sqft)'] = utils.get_section_text(soup, 'Size (sqft)', 'dt', 'dd')

        ad_data['Furnished'] = utils.get_section_text(soup, 'Furnished', 'dt', 'dd')

        ad_data['Air Conditioning'] = utils.get_section_text(soup, 'Air Conditioning', 'dt', 'dd')

        ad_data['Personal Outdoor Space'] = utils.get_section_text(soup, 'Personal Outdoor Space', 'h4', 'ul')

        ad_data['Smoking Permitted'] = utils.get_section_text(soup, 'Smoking Permitted', 'dt', 'dd')

        ad_data['Appliances'] = utils.get_multiple_section_text(soup, 'Appliances')

        ad_data['Amenities'] = utils.get_multiple_section_text(soup, 'Amenities')

        # Extract description
        description_elm = soup.select_one('.descriptionContainer-2067035870 p')
        ad_data['Description'] = description_elm.text.strip() if description_elm else None

        # Extract visit counter
        visit_counter_elem = soup.select_one('.visitCounter-204515568 span')
        ad_data['Visit Counter'] = visit_counter_elem.text.strip() if visit_counter_elem else None

        ad_data['url'] = url

        # Append the extracted data to the list
        data.append(ad_data)

        counter += 1
        print("Number ", counter, ' and URL ', url)

# Create a DataFrame from the collected data
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv(f'kijiji_rental_ads_{counter}.csv', index=False)

# Delete the original CSV file containing URLs
os.remove('kijiji_rental_ads_url.csv')
print("Delete csv kijiji_rental_ads_url.csv")

utils.print_time_info(start_time, datetime.now())
# Out:
# Number  1  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/renovated-bachelor-king-and-jameson-id-2541/1683888315
# Number  2  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/renovated-two-bedroom-queen-and-victoria-park-id-3192/1686025060
# Number  3  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/fully-renovated-2-bedroom-in-etobicoke/1639869260
# Number  4  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/831-kennedy-road-831-kennedy-apartment-for-rent/1686827384
# Number  5  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/renovated-two-bedroom-don-mills-and-lawrence-id-3244/1687384233
# Number  6  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/private-basement-apartment-located-at-kennedy-lawrence-east/1685515558
# Number  7  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/105-west-lodge-1-bedroom-apartment-in-the-heart-of-parkdale-ap/1682857424
# Number  8  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/105-west-lodge-studio-apartment-in-the-heart-of-parkdale-apart/1678918599
# Number  9  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bdm-for-rent-at-junction-factory-dundas-w-runnymede-rd/1682800714
# Number  10  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2-bdm-den-for-rent-at-junction-factory-dundas-w-runnymede/1682800718
# Number  11  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/jr-1-bdm-for-rent-at-junction-factory-dundas-w-runnymede-rd/1683186329
# Number  12  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/a-private-room-in-a-2-bedroom-condo-apartment/1688038686
# Number  13  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/upscale-large-1-bedroom-suite-yonge-and-st-clair-air-conditioned/1665241670
# Number  14  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/jr-1-bdrm-fifty-on-the-park/1683353254
# Number  15  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bdrm-den-1-month-free/1681656139
# Number  16  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bdrm-king-west/1683989353
# Number  17  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bdrm-den-1-month-free/1665475765
# Number  18  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/bathurst-finch-male-only-month-to-month-rental-ttc-subway/1688036557
# Number  19  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/beautiful-furnished-studio-in-the-core-of-downtown-toronto/1505825513
# Number  20  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-apartment-near-bay-and-bloor/1652656996
# Number  21  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/spacious-2-bedroom-apartment-near-bay-and-bloor/1651944034
# Number  22  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/prime-downtown-location-bachelor-apartment-near-bay-and-bloor/1685406898
# Number  23  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/condo-apartment-rentals-from-1800/1685300643
# Number  24  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/davisville-village-apartments-2-bdrm-available-at-111-davisvil/1684053324
# Number  25  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/davisville-village-apartments-1-bdrm-available-at-111-davisvil/1681242987
# Number  26  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/davisville-village-apartments-bachelor-available-at-111-davisv/1669327539
# Number  27  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/one-bedroom-apartment-yonge-sheppard-subway/1688034934
# Number  28  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/bright-beautiful-3-1-bedroom-home-backing-ravine-etobicok/1688034846
# Number  29  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/room-for-rent-for-8-linville-rd-scarborough/1688032503
# Number  30  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/gorgeous-1-bedroom-apt-steps-to-keelesdale-subway-station/1688032229
# Number  31  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/beutiful-3-bedroom-main-floor-of-house-dufferin-and-lawrence/1688032210
# Number  32  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/studio-with-den-bedroom-all-inclusive-in-bloor-west-village/1688032173
# Number  33  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/chatsworth-apartments-1-bdrm-available-at-2928-yonge-street-t/1663969893
# Number  34  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2-bedroom-2-bath-for-rent-in-etobicoke-1-month-free-rent/1652042901
# Number  35  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-den-for-rent-in-etobicoke-1-month-free-rent/1648336960
# Number  36  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-available-near-eglinton-square-shopping-centre/1680546255
# Number  37  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/3-bedroom-available-call-now/1687052879
# Number  38  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-available-toronto-call-now/1684434540
# Number  39  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-available-1000-off-fmr-east-york/1686629991
# Number  40  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-vp-eglinton-call-now/1648228361
# Number  41  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/studio-vp-eglinton-500-off-fmr-call-now/1677742257
# Number  42  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-available-thorncliffe-park-overlea-blvd/1686629983
# Number  43  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2-bedroom-available-scarborough-call-now/1687052801
# Number  44  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-available-in-scarborough-250-off-fmr-call-now/1678658182
# Number  45  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/chaplin-crescent-apartments-1-bdrm-available-at-321-chaplin-cr/1670650233
# Number  46  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2bdr-basement-apartment-for-monthly-rent-in-etobicoke/1688030604
# Number  47  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/treatment-room-for-rent-at-sol-medical-spa-forest-hill-toronto/1677000200
# Number  48  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2-bedroom-for-rent-in-midtown-torontos-leaside-neighourhood/1674565016
# Number  49  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-coach-house-for-rent-in-midtown-toronto/1683186335
# Number  50  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-basement-apartment/1684213412
# Number  51  and URL  https://www.kijiji.ca/v-storage-parking/city-of-toronto/parking-kingston-and-warden-id-3160/1683888295
# Number  52  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-for-rent-in-midtown-torontos-leaside-neighourhood/1674565059
# Number  53  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/x-large-room-for-rent-near-york-u/1688036846
# Number  54  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/basement-for-rent/1688036601
# Number  55  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/bathurst-finch-male-only-month-to-month-rental-ttc-subway/1688036557
# Number  56  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/room-for-rent-st-clair-dufferin-from-april-1/1688036399
# Number  57  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/room-for-rent-for-utsc-centennial-college-student/1688036109
# Number  58  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/private-rooms-sharing-rooms-available/1688035903
# Number  59  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/find-office-space-in-spaces-325-front-street-for-1-person/1627996392
# Number  60  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/book-a-reserved-coworking-spot-or-hot-desk-in-queen-bay/1523240220
# Number  61  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/book-a-reserved-coworking-spot-or-hot-desk-in-yonge-and-sheppard/1523134540
# Number  62  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/private-office-space-for-3-persons-in-don-mills/1649069518
# Number  63  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/access-professional-coworking-space-in-yonge-and-richmond-centre/1520807555
# Number  64  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/fully-serviced-private-office-space-for-you-and-your-team/1523134625
# Number  65  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/access-professional-coworking-space-in-eaton-centre/1520767771
# Number  66  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/fully-serviced-private-office-space-for-you-and-your-team/1522981494
# Number  67  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/private-office-space-tailored-to-your-business-unique-needs/1520256800
# Number  68  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/fully-serviced-private-office-space-for-you-and-your-team-in-eat/1520256443
# Number  69  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/access-professional-coworking-space-in-queen-richmond-centre/1520465655
# Number  70  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/private-office-space-for-3-persons-in-islington-station/1520465711
# Number  71  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/access-professional-coworking-space-in-liberty-village/1520465659
# Number  72  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/tailor-made-dream-offices-for-1-person-in-spaces-the-junction/1513599130
# Number  73  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/private-office-space-tailored-to-your-business-unique-needs/1513833908
# Number  74  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/private-office-space-for-2-persons-in-first-canadian-place/1519645401
# Number  75  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/book-a-reserved-coworking-spot-or-hot-desk-in-yonge-shuter/1513264745
# Number  76  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/private-office-space-for-2-persons-in-brookfield-place/1512520835
# Number  77  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/private-office-space-for-3-persons-in-liberty-village/1505800316
# Number  78  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/beautiful-furnished-studio-in-the-core-of-downtown-toronto/1505825513
# Number  79  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-apartment-near-bay-and-bloor/1652656996
# Number  80  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/spacious-2-bedroom-apartment-near-bay-and-bloor/1651944034
# Number  81  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/prime-downtown-location-bachelor-apartment-near-bay-and-bloor/1685406898
# Number  82  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/room-for-rent/1688035775
# Number  83  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/bright-corner-bedroom-with-amazing-lake-views/1688035673
# Number  84  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/fully-furnished-amazing-downtown-toronto-studio/1687184248
# Number  85  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/condo-apartment-rentals-from-1800/1685300643
# Number  86  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/private-room-rental/1682724859
# Number  87  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/eglinton-west-subway-station-nice-bedroom/1688035558
# Number  88  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/a-room-for-renting/1688035496
# Number  89  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/seneca-college-nice-bedroom-in-north-york/1688035423
# Number  90  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/davisville-village-apartments-2-bdrm-available-at-111-davisvil/1684053324
# Number  91  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/davisville-village-apartments-1-bdrm-available-at-111-davisvil/1681242987
# Number  92  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/davisville-village-apartments-bachelor-available-at-111-davisv/1669327539
# Number  93  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/3-bedroom-apartment-north-york-don-valley-parkway-brookbanks-dr/1667146309
# Number  94  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/600-kingston-road-kingston-estates-apartment-for-rent/1686333422
# Number  95  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/large-3-bedroom-basement-apartment-keele-st-and-lawrence-ave-w/1687583582
# Number  96  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/50-driftwood-ruby-heights-apartment-for-rent/1684150841
# Number  97  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/forest-hill-residences-3-bedroom-apartment-for-rent/1687441956
# Number  98  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/1bed-bath-sublease-private-room-in-toronto/1687862960
# Number  99  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/davisville-village-apartments-1-bdrm-available-at-111-davisvil/1681242987
# Number  100  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/davisville-village-apartments-bachelor-available-at-111-davisv/1669327539
# Number  101  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/room-for-rent-available-april-1st/1688035355
# Number  102  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/room-for-rent/1688035354
# Number  103  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/one-bedroom-apartment-yonge-sheppard-subway/1688034934
# Number  104  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/bright-beautiful-3-1-bedroom-home-backing-ravine-etobicok/1688034846
# Number  105  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/one-bedroom-for-rent-st-clair-and-dufferin/1688034815
# Number  106  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/room-for-a-professional-female-yonge-sheppard-subway/1688034604
# Number  107  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/private-room-rent-only-for-male/1688034588
# Number  108  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/living-room-space-in-one-bedroom/1688034497
# Number  109  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/large-room-near-bus-and-go-train-w-brand-new-kitchen-appliances/1677862581
# Number  110  and URL  https://www.kijiji.ca/v-short-term-rental/city-of-toronto/lux-furnished-bachelor-close-to-eaton-centre/1688034377
# Number  111  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/shop-at-don-mills-fully-furnished-bachelor-condo/1688034220
# Number  112  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bed-1-bath-townhouse-condo/1688034190
# Number  113  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/space-in-the-living-room-for-rent/1688034123
# Number  114  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/roommate-at-bathurst-and-sheppard/1688034024
# Number  115  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-den-1-bath-condo-available-for-lease-in-toronto/1688034007
# Number  116  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/spacious-2-bed-1-bath-walkout-basement/1688033933
# Number  117  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/3-bdrms-2-bathrms-house-for-rent/1688033899
# Number  118  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2bed-den-2-bath-new-condo-at-bloor-islington-toronto/1688033864
# Number  119  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/furnished-room-for-rent/1688033647
# Number  120  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/large-bedroom-available-by-fairview-mall-female-only/1688033330
# Number  121  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/one-bedroom-suite-lakeshore-for-rent-17-bathurst-street/1688033316
# Number  122  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/private-room-in-crockamhil-scarborough-for-females-only/1688033290
# Number  123  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/2-bedroom-basement-for-rent/1688033092
# Number  124  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/therapeutic-office-rooms-for-rent-by-hour-downtown-toronto/1680531178
# Number  125  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/1030-sheppard-av-west-allen-rd/1685594732
# Number  126  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/immediately-large-room-for-rent-male-only-ground-floor/1688032909
# Number  127  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/spacious-one-bedroom-basement-with-private-washroom-and-kitchen/1688032819
# Number  128  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/spacious-one-bedroom-basement-with-private-washroom-and-kitchen/1688032786
# Number  129  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/yonge-and-finch-1-bedroom-studio-unit-no-sharing-with-balcony/1688032586
# Number  130  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/private-room-for-rent/1688032558
# Number  131  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/room-for-rent-for-8-linville-rd-scarborough/1688032503
# Number  132  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/room-in-female-house-avail-may-1-shared-acc/1688032329
# Number  133  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/sharing-room-for-rent-pharmacy-ave/1688032279
# Number  134  and URL  https://www.kijiji.ca/v-commercial-office-space/city-of-toronto/leasing-office-and-design-studios:-lower-junction/1444582229
# Number  135  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/gorgeous-1-bedroom-apt-steps-to-keelesdale-subway-station/1688032229
# Number  136  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/fully-furnished-executive-basement-rental-in-leslieville/1688032230
# Number  137  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/beutiful-3-bedroom-main-floor-of-house-dufferin-and-lawrence/1688032210
# Number  138  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/studio-with-den-bedroom-all-inclusive-in-bloor-west-village/1688032173
# Number  139  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/davisville-village-apartments-2-bdrm-available-at-111-davisvil/1684053324
# Number  140  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/1-minute-to-ttc-subway:-clean-room-danforth-and-main/1687555418
# Number  141  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/a-deal-tech-support-for-furnished-1-bdrm-bsmt-apt/1687492377
# Number  142  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2-bedroom-2-bathroom-high-rise-condo-in-toronto-for-rent/1687835721
# Number  143  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/york-university-village-rooms-female-only-due-to-shared-areas/1686755417
# Number  144  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/900-for-rent-eglinton-martin-grove-416-624-5844/1687440676
# Number  145  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/studio-with-den-bedroom-all-inclusive-in-bloor-west-village/1688032173
# Number  146  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/chatsworth-apartments-1-bdrm-available-at-2928-yonge-street-t/1663969893
# Number  147  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/lawrence-and-yonge-5-min-to-yonge-subway/1688032028
# Number  148  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2-bedroom-2-bath-for-rent-in-etobicoke-1-month-free-rent/1652042901
# Number  149  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-den-for-rent-in-etobicoke-1-month-free-rent/1648336960
# Number  150  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-available-near-eglinton-square-shopping-centre/1680546255
# Number  151  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/3-bedroom-available-call-now/1687052879
# Number  152  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-available-toronto-call-now/1684434540
# Number  153  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-available-1000-off-fmr-east-york/1686629991
# Number  154  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-vp-eglinton-call-now/1648228361
# Number  155  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/studio-vp-eglinton-500-off-fmr-call-now/1677742257
# Number  156  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-available-thorncliffe-park-overlea-blvd/1686629983
# Number  157  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/one-bedroom-den-university-dundas-subway-12-f-600-sq-ft-may-1/1688031851
# Number  158  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2-bedroom-available-scarborough-call-now/1687052801
# Number  159  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bedroom-available-in-scarborough-250-off-fmr-call-now/1678658182
# Number  160  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/chaplin-crescent-apartments-1-bdrm-available-at-321-chaplin-cr/1670650233
# Number  161  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/high-park-brand-new-coach-house-for-lease/1687586070
# Number  162  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/sharing-room-for-rent-centennial-college/1688031738
# Number  163  and URL  https://www.kijiji.ca/v-short-term-rental/city-of-toronto/private-room-with-ensuite-bathroom/1688031686
# Number  164  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/private-room-in-single-family-home-n-of-eglinton-w-and-weston-rd/1688031535
# Number  165  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/april-1st-room-for-rent-at-eglinton-and-caledonia/1688031420
# Number  166  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2bdr-basement-apartment-for-monthly-rent-in-etobicoke/1688030604
# Number  167  and URL  https://www.kijiji.ca/v-room-rental-roommate/city-of-toronto/private-bathroom-long-term-furnished-room-male-only/1688030533
# Number  168  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/lrg-2-bedroom-jane-dundas-baby-point-junction-west/1684558308
# Number  169  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1132-glengrove-main-floor/1688028480
# Number  170  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/brand-new-2-bedroom-suite-for-rent-at-lytton-heights/1688028606
# Number  171  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2-bedroom-king-and-bathurst/1688028447
# Number  172  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2-story-2-bedroom-apartments/1688028857
# Number  173  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/spacious-and-clean-2-bedroom-units/1688028429
# Number  174  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/spacious-and-clean-bachelor-unit/1688028511
# Number  175  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/newly-renovated-large-3-4-bedroom-apartment-for-rent-eglinton/1688028655
# Number  176  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/royal-york-gardens/1688028533
# Number  177  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/beautiful-and-modern-1-bedroom-unit-steps-from-glencairn-subway/1688028637
# Number  178  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/waterfront-living-1-bed-condo-38-dan-leckie-way/1688029067
# Number  179  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2bd-at-45-la-rose-avenue-richview-developments/1688028938
# Number  180  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/stunning-modern-new-build-2-bedroom-2-bathroom-with-a-back-patio/1688029049
# Number  181  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/recently-renovated-executive-rental-south-annex-5800-utilit/1688029069
# Number  182  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2-bed-3-bath-condo-townhouse-in-south-etobicoke/1688028624
# Number  183  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/2-bed-1-bath-home-in-the-annex/1688028590
# Number  184  and URL  https://www.kijiji.ca/v-apartments-condos/city-of-toronto/1-bed-1-bath-basement-apartment-in-prime-location-beside-cne/1688029151
# Delete csv kijiji_rental_ads_url.csv
# Time elapsed: 0 hours, 6 minutes, 51 seconds
